# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
e = pd.read_csv(r"C:\ThirdYear_Notes\Practicals\DSBDA\Employee_2.csv")

# 1. Summary stats on age & salary
print("\n")
print("Summary Stats:::\n")
print(e[['Age','Salary']].agg(['mean','median','min']))

# 2. Group income by age_group
print("\n")
print("Group By:::\n")
print(e.groupby('Education')['Salary'].describe())
vals = e['Salary'].tolist()
print("\n")
# 3. JOB_ID counts
print("JOB ID Counts:::\n")
print(e['Education'].value_counts())

# 4. Visualization (salary histogram)
print("\n")
print("Salary Histogram:::\n")
sns.histplot(e['Salary'], bins=20)
plt.show()
# Out:
# Summary Stats:::
#
#               Age         Salary
# mean    26.310459  224240.323693
# median  26.000000  226605.500000
# min     22.000000   50135.000000
#
#
# Group By:::
#
#             count           mean            std      min       25%       50%  \
# Education
# Bachelors  1384.0  225417.347543  101085.642035  50136.0  138229.0  230032.0
# Masters     351.0  220149.592593   98345.186433  51513.0  139004.0  220703.0
# PHD          63.0  221174.380952  109375.985511  50135.0  132510.0  206486.0
#
#                 75%       max
# Education
# Bachelors  311550.0  399785.0
# Masters    301576.5  398111.0
# PHD        328008.0  399612.0
#
#
# JOB ID Counts:::
#
# Education
# Bachelors    1391
# Masters       353
# PHD            63
# Name: count, dtype: int64
#
#
# Salary Histogram:::
